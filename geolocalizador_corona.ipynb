# %% [markdown]
# Geolocalizador de coordenadas geográficas de endereços. As vezes, temos um dataframe com uma ou mais colunas de localização, entretanto para criar gráficos com geolocalizadores é necessário adicionar as latitudes e longitudes, para isso esse código serve. Uma recomendação é criar um coluna com todas as informações relevantes ao problema, por exemplo: no dataframe abaixo, a grande maioria dos pontos foi encontrada em Maceió, porém outros foram espalhadas em todo o Brasil, provavelmente devido a nomes de localidades iguais. Para resolver esse problema o indicado é ter uma coluna com todas as infromações que são utéis para achar o endereço. Eu utilizei municipio e bairro, mas vc pode adicionar uma string manual que ajude nessa busca.
# Referência: 'https://www.youtube.com/watch?v=asSNKH_ee0M&ab_channel=Programa%C3%A7%C3%A3oDin%C3%A2mica'

# %%
import pandas as pd
#url = 'https://dados.al.gov.br/catalogo/dataset/821e5f37-0be4-4a5e-948c-59d95e538773/resource/ec77b1d0-684d-48c5-9196-23ff216c9dfb/download/bairrosexcel2-1.csv'
df = pd.read_csv('/content/censoPorBairro.csv')  # Especificando a codificação correta
df
# Out:
#                                BAIRRO  CASOS_CONFIRMADOS  \
# 0                               Acupe               1375
# 1                           Aeroporto                 20
# 2                        Aguas Claras               3371
# 3                   Alto da Terezinha                424
# 4                     Alto das Pombas                633
# ..                                ...                ...
# 163                      Vila Canaria               1071
# 164                        Vila Laura               2267
# 165  Vila Ruy Barbosa/Jardim Cruzeiro               1575
# 166                      Vista Alegre                134
# 167                           Vitoria                766
#
#      COEFICIENTE_INCIDENCIA  POPULACAO  RECUPERADOS
# 0                    122.63      11213         1319
# 1                      0.00          0           18
# 2                     91.04      37029         3212
# 3                     30.26      14010          403
# 4                    165.58       3823          618
# ..                      ...        ...          ...
# 163                   95.47      11218         1034
# 164                  156.09      14524         2194
# 165                   80.99      19448         1488
# 166                    0.00          0          131
# 167                  146.60       5225          727
#
# [168 rows x 5 columns]

# %%
df['CIDADE'] = 'Salvador'
df
# Out:
#                                BAIRRO  CASOS_CONFIRMADOS  \
# 0                               Acupe               1375
# 1                           Aeroporto                 20
# 2                        Aguas Claras               3371
# 3                   Alto da Terezinha                424
# 4                     Alto das Pombas                633
# ..                                ...                ...
# 163                      Vila Canaria               1071
# 164                        Vila Laura               2267
# 165  Vila Ruy Barbosa/Jardim Cruzeiro               1575
# 166                      Vista Alegre                134
# 167                           Vitoria                766
#
#      COEFICIENTE_INCIDENCIA  POPULACAO  RECUPERADOS    CIDADE
# 0                    122.63      11213         1319  Salvador
# 1                      0.00          0           18  Salvador
# 2                     91.04      37029         3212  Salvador
# 3                     30.26      14010          403  Salvador
# 4                    165.58       3823          618  Salvador
# ..                      ...        ...          ...       ...
# 163                   95.47      11218         1034  Salvador
# 164                  156.09      14524         2194  Salvador
# 165                   80.99      19448         1488  Salvador
# 166                    0.00          0          131  Salvador
# 167                  146.60       5225          727  Salvador
#
# [168 rows x 6 columns]

# %%
df['procurar'] = df['CIDADE'].str.cat(df['BAIRRO'], sep=', ')

# %%
df
# Out:
#                                BAIRRO  CASOS_CONFIRMADOS  \
# 0                               Acupe               1375
# 1                           Aeroporto                 20
# 2                        Aguas Claras               3371
# 3                   Alto da Terezinha                424
# 4                     Alto das Pombas                633
# ..                                ...                ...
# 163                      Vila Canaria               1071
# 164                        Vila Laura               2267
# 165  Vila Ruy Barbosa/Jardim Cruzeiro               1575
# 166                      Vista Alegre                134
# 167                           Vitoria                766
#
#      COEFICIENTE_INCIDENCIA  POPULACAO  RECUPERADOS    CIDADE  \
# 0                    122.63      11213         1319  Salvador
# 1                      0.00          0           18  Salvador
# 2                     91.04      37029         3212  Salvador
# 3                     30.26      14010          403  Salvador
# 4                    165.58       3823          618  Salvador
# ..                      ...        ...          ...       ...
# 163                   95.47      11218         1034  Salvador
# 164                  156.09      14524         2194  Salvador
# 165                   80.99      19448         1488  Salvador
# 166                    0.00          0          131  Salvador
# 167                  146.60       5225          727  Salvador
#
#                                        procurar
# 0                               Salvador, Acupe
# 1                           Salvador, Aeroporto
# 2                        Salvador, Aguas Claras
# 3                   Salvador, Alto da Terezinha
# 4                     Salvador, Alto das Pombas
# ..                                          ...
# 163                      Salvador, Vila Canaria
# 164                        Salvador, Vila Laura
# 165  Salvador, Vila Ruy Barbosa/Jardim Cruzeiro
# 166                      Salvador, Vista Alegre
# 167                           Salvador, Vitoria
#
# [168 rows x 7 columns]

# %%
df['procurar']
# Out:
# 0                                 Salvador, Acupe
# 1                             Salvador, Aeroporto
# 2                          Salvador, Aguas Claras
# 3                     Salvador, Alto da Terezinha
# 4                       Salvador, Alto das Pombas
#                           ...
# 163                        Salvador, Vila Canaria
# 164                          Salvador, Vila Laura
# 165    Salvador, Vila Ruy Barbosa/Jardim Cruzeiro
# 166                        Salvador, Vista Alegre
# 167                             Salvador, Vitoria
# Name: procurar, Length: 168, dtype: object

# %%
df['Município'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Município'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-8c11f84ca373> in <cell line: 1>()
# ----> 1 df['Município'].unique()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Município'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   BAIRRO                  168 non-null    object
#  1   CASOS_CONFIRMADOS       168 non-null    int64
#  2   COEFICIENTE_INCIDENCIA  168 non-null    float64
#  3   POPULACAO               168 non-null    int64
#  4   RECUPERADOS             168 non-null    int64
#  5   CIDADE                  168 non-null    object
#  6   procurar                168 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 9.3+ KB

# %%
# !pip install geocoder
# Out:
# Requirement already satisfied: geocoder in /usr/local/lib/python3.10/dist-packages (1.38.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from geocoder) (8.1.7)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from geocoder) (0.18.3)
# Requirement already satisfied: ratelim in /usr/local/lib/python3.10/dist-packages (from geocoder) (0.1.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from geocoder) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from geocoder) (1.16.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ratelim->geocoder) (4.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->geocoder) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->geocoder) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->geocoder) (2.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->geocoder) (2023.7.22)

# %%
from geopy.geocoders import Nominatim

# %%
locator = Nominatim(user_agent='MyGeocoder')
location = locator.geocode("Avenida Braulino Santos, 571")
location.point
# Out:
# Point(-14.8661995, -40.8206733, 0.0)

# %%
from geopy.extra.rate_limiter import RateLimiter

# %%
geocode = RateLimiter(locator.geocode, min_delay_seconds=1)

# %%
df['raw'] = df['procurar'].apply(geocode)

# %%
df['raw'][0]
# Out:
# Location(Acupe, Salvador, Região Geográfica Imediata de Salvador, Região Metropolitana de Salvador, Região Geográfica Intermediária de Salvador, Bahia, Região Nordeste, Brasil, (-12.9927448, -38.4937012, 0.0))

# %%
df['raw'].isna().sum()
# Out:
# 6

# %%
df.dropna(subset=['raw'], inplace=True)
df['raw'].isna().sum()
# Out:
# 0

# %%
df['LATITUDE'] = df['raw'].apply(lambda loc: loc.latitude if loc else None)
df['LONGITUDE'] = df['raw'].apply(lambda loc: loc.longitude if loc else None)
df['POINT'] = df['raw'].apply(lambda loc: loc.point if loc else None)

# %%
df
# Out:
#                                BAIRRO  CASOS_CONFIRMADOS  \
# 0                               Acupe               1375
# 1                           Aeroporto                 20
# 2                        Aguas Claras               3371
# 3                   Alto da Terezinha                424
# 4                     Alto das Pombas                633
# ..                                ...                ...
# 163                      Vila Canaria               1071
# 164                        Vila Laura               2267
# 165  Vila Ruy Barbosa/Jardim Cruzeiro               1575
# 166                      Vista Alegre                134
# 167                           Vitoria                766
#
#      COEFICIENTE_INCIDENCIA  POPULACAO  RECUPERADOS    CIDADE  \
# 0                    122.63      11213         1319  Salvador
# 1                      0.00          0           18  Salvador
# 2                     91.04      37029         3212  Salvador
# 3                     30.26      14010          403  Salvador
# 4                    165.58       3823          618  Salvador
# ..                      ...        ...          ...       ...
# 163                   95.47      11218         1034  Salvador
# 164                  156.09      14524         2194  Salvador
# 165                   80.99      19448         1488  Salvador
# 166                    0.00          0          131  Salvador
# 167                  146.60       5225          727  Salvador
#
#                                        procurar  \
# 0                               Salvador, Acupe
# 1                           Salvador, Aeroporto
# 2                        Salvador, Aguas Claras
# 3                   Salvador, Alto da Terezinha
# 4                     Salvador, Alto das Pombas
# ..                                          ...
# 163                      Salvador, Vila Canaria
# 164                        Salvador, Vila Laura
# 165  Salvador, Vila Ruy Barbosa/Jardim Cruzeiro
# 166                      Salvador, Vista Alegre
# 167                           Salvador, Vitoria
#
#                                                    raw   LATITUDE  LONGITUDE  \
# 0    (Acupe, Salvador, Região Geográfica Imediata d... -12.992745 -38.493701
# 1    (Aeroporto, Salvador, Região Geográfica Imedia... -12.917442 -38.329475
# 2    (Águas Claras, Salvador, Região Geográfica Ime... -12.888063 -38.434540
# 3    (Alto da Terezinha, Salvador, Região Geográfic... -12.881484 -38.477249
# 4    (Alto das Pombas, Salvador, Região Geográfica ... -13.001166 -38.513711
# ..                                                 ...        ...        ...
# 163  (Vila Canária, Jardim Cajazeiras, Salvador, Re... -12.914008 -38.443364
# 164  (Vila Laura, Salvador, Região Geográfica Imedi... -12.970721 -38.488233
# 165  (Vila Ruy Barbosa / Jardim Cruzeiro, Salvador,... -12.931601 -38.499495
# 166  (Vista Alegre, Coutos, Salvador, Região Geográ... -12.852824 -38.461395
# 167  (Vitória, Salvador, Região Geográfica Imediata... -12.992978 -38.526319
#
#                                     POINT
# 0    12 59m 33.8813s S, 38 29m 37.3243s W
# 1      12 55m 2.793s S, 38 19m 46.1096s W
# 2    12 53m 17.0284s S, 38 26m 4.34344s W
# 3     12 52m 53.3424s S, 38 28m 38.096s W
# 4     13 0m 4.19832s S, 38 30m 49.3603s W
# ..                                    ...
# 163  12 54m 50.4275s S, 38 26m 36.1088s W
# 164   12 58m 14.596s S, 38 29m 17.6374s W
# 165  12 55m 53.7647s S, 38 29m 58.1813s W
# 166  12 51m 10.1664s S, 38 27m 41.0222s W
# 167  12 59m 34.7222s S, 38 31m 34.7473s W
#
# [162 rows x 11 columns]

# %%
df['raw']
# Out:
# 0      (Acupe, Salvador, Região Geográfica Imediata d...
# 1      (Aeroporto, Salvador, Região Geográfica Imedia...
# 2      (Águas Claras, Salvador, Região Geográfica Ime...
# 3      (Alto da Terezinha, Salvador, Região Geográfic...
# 4      (Alto das Pombas, Salvador, Região Geográfica ...
#                              ...
# 163    (Vila Canária, Jardim Cajazeiras, Salvador, Re...
# 164    (Vila Laura, Salvador, Região Geográfica Imedi...
# 165    (Vila Ruy Barbosa / Jardim Cruzeiro, Salvador,...
# 166    (Vista Alegre, Coutos, Salvador, Região Geográ...
# 167    (Vitória, Salvador, Região Geográfica Imediata...
# Name: raw, Length: 168, dtype: object

# %%
from google.colab import files

covid_geoloc = 'covid_bairro.csv'
df.to_csv(covid_geoloc, index=False)


files.download(covid_geoloc)

# %%
pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2023.7.22)

# %%
import folium
mapa=folium.Map(
    location=[df['LATITUDE'].mean(), df['LONGITUDE'].mean()],
    zoom_start=10)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_777fc0db8c46a711cc76b1e9ec02bed7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_777fc0db8c46a711cc76b1e9ec02bed7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_777fc0db8c46a711cc76b1e9ec02bed7 = L.map(
#                 &quot;map_777fc0db8c46a711cc76b1e9ec02bed7&quot;,
#                 {
#                     center: [-12.493228541358024, -38.60934119825692],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d68a0c8d8f2fdac6f7503a96666f638e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_777fc0db8c46a711cc76b1e9ec02bed7);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# Função para criar pop-up com latitude e longitude
def create_popup(row):
    popup_text = f"Latitude: {row['LATITUDE']}<br>Longitude: {row['LONGITUDE']}<br>Bairro: {row['BAIRRO']}<br>Número de Casos: {row['CASOS_CONFIRMADOS']}"
    return folium.Popup(popup_text, max_width=400)

# Criar um mapa
mapa = folium.Map(location=[ 12.9144042, -38.4368023,], zoom_start=12)  # Substitua com as coordenadas iniciais desejadas

# Normalizar a coluna "CASOS_CONFIRMADOS" para o intervalo desejado (por exemplo, 1 a 10)
min_value = df['CASOS_CONFIRMADOS'].min()
max_value = df['CASOS_CONFIRMADOS'].max()

df['RAIO_NORMALIZADO'] = df['CASOS_CONFIRMADOS'].apply(lambda x: 1 + (x - min_value) / (max_value - min_value) * 9)

df['RAIO_NORMALIZADO'] = df['RAIO_NORMALIZADO']*2

# Adicione os marcadores ao mapa com pop-ups e raio personalizado
for index, row in df.iterrows():
    folium.CircleMarker(
        location=[row['LATITUDE'], row['LONGITUDE']],
        popup=create_popup(row),
        radius=row['RAIO_NORMALIZADO'],
        tooltip=row['BAIRRO'],
        fill=True,  # Preencher o círculo
        fill_color= "blue",  # Especificar a cor de preenchimento
        fill_opacity=0.6
    ).add_to(mapa)

mapa.save('mapa.html')

# Exiba o mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_04ba07676b6d0b3808f007f57145bd4f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_04ba07676b6d0b3808f007f57145bd4f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_04ba07676b6d0b3808f007f57145bd4f = L.map(
#                 &quot;map_04ba07676b6d0b3808f007f57145bd4f&quot;,
#                 {
#                     center: [12.9144042, -38.4368023],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e6ff9dde213281ea10a214b57a0fa847 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_04ba07676b6d0b3808f007f57145bd4f);
#
#
#             var circle_marker_b894ea1ade8c63ca8a68dc01cc8b6fe0 = L.circleMarker(
#                 [-12.9927448, -38.4937012],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4.5241081525650255, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_04ba07676b6d0b3808f007f57145bd4f);
#
#
#         var popup_7f5b198c0588c3bd2b9c6b89dacddb0e = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_a909c99b262577c83c8a15bc7d267a5f = $(`&lt;div id=&quot;html_a909c99b262577c83c8a15bc7d267a5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: -12.9927448&lt;br&gt;Longitude: -38.4937012&lt;br&gt;Bairro: Acupe&lt;br&gt;Número de Casos: 1375&lt;/div&gt;`)[0];
#                 popup_7f5b198c0588c3bd2b9c6b89dacddb0e.setContent(html_a909c99b262577c83c8a15bc7d267a5f);
#
#
#
#         circle_marker_b894ea1ade8c63ca8a68dc01cc8b6fe0.bindPopup(popup_7f5b198c0588c3bd2b9c6b89dacddb0e)
#         ;
#
#
#
#
#             circle_marker_b894ea1ade8c63ca8a68dc01cc8b6fe0.bindTooltip(
#                 `&lt;div&gt;
#                      Acupe
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_82396e252c401b400b4180b0d94ad783 = L.circleMarker(
#                 [-12.9174425, -38.3294749],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2.016654672560913, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_04ba07676b6d0b3808f007f57145bd4f);
#
#
#         var popup_f78ecb7f2804906b0aed0c5131e6d60f = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_070e83fc9b063d768a7e81216c03b4d2 = $(`&lt;div id=&quot;html_070e83fc9b063d768a7e81216c03b4d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: -12.9174425&lt;br&gt;Longitude: -38.3294749&lt;br&gt;Bairro: Aeroporto&lt;br&gt;Número de Casos: 20&lt;/div&gt;`)[0];
#                 popup_f78ecb7f2804906b0aed0c5131e6d60f.setContent(html_070e83fc9b063d768a7e81216c03b4d2);
#
#
#
#         circle_marker_82396e252c401b400b4180b0d94ad783.bindPopup(popup_f78ecb7f2804906b0aed0c5131e6d60f)
#         ;
#
#
#
#
#             circle_marker_82396e252c401b400b4180b0d94ad783.bindTooltip(
#                 `&lt;div&gt;
#                      Aeroporto
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_113baa4443214dd8d1ecc48d5e4a3448 = L.circleMarker(
#                 [-12.88806345, -38.43453984517778],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8.217744422740825, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_04ba07676b6d0b3808f007f57145bd4f);
#
#
#         var popup_5a214a522201eb38643686f59b03dd9e = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_99f66c23e838c38239211d09116899ca = $(`&lt;div

# %%
import folium

# Função para criar pop-up com latitude e longitude
def create_popup(row):
    popup_text = f"Latitude: {row['LATITUDE']}<br>Longitude: {row['LONGITUDE']}<br>Bairro: {row['BAIRRO']}<br>Número de Casos: {row['COEFICIENTE_INCIDENCIA']}"
    return folium.Popup(popup_text, max_width=400)

# Criar um mapa
mapa = folium.Map(location=[ 12.9144042, -38.4368023,], zoom_start=12)  # Substitua com as coordenadas iniciais desejadas

# Normalizar a coluna "CASOS_CONFIRMADOS" para o intervalo desejado (por exemplo, 1 a 10)
min_value = df['COEFICIENTE_INCIDENCIA'].min()
max_value = df['COEFICIENTE_INCIDENCIA'].max()

df['RAIO_NORMALIZADO'] = df['COEFICIENTE_INCIDENCIA'].apply(lambda x: 1 + (x - min_value) / (max_value - min_value) * 9)

df['RAIO_NORMALIZADO'] = df['RAIO_NORMALIZADO']*2

# Adicione os marcadores ao mapa com pop-ups e raio personalizado
for index, row in df.iterrows():
    folium.CircleMarker(
        location=[row['LATITUDE'], row['LONGITUDE']],
        popup=create_popup(row),
        radius=row['RAIO_NORMALIZADO'],
        tooltip=row['BAIRRO'],
        fill=True,  # Preencher o círculo
        fill_color= "red",  # Especificar a cor de preenchimento
        fill_opacity=0.6
    ).add_to(mapa)

mapa.save('mapa.html')

# Exiba o mapa
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0e18268ec9adc704a29aeef00262a2d2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0e18268ec9adc704a29aeef00262a2d2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0e18268ec9adc704a29aeef00262a2d2 = L.map(
#                 &quot;map_0e18268ec9adc704a29aeef00262a2d2&quot;,
#                 {
#                     center: [12.9144042, -38.4368023],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_05203f23fb30b305fab1bdadc2e9a9aa = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0e18268ec9adc704a29aeef00262a2d2);
#
#
#             var circle_marker_4c0ca6dc8c572f05066d9b4073d7ba3e = L.circleMarker(
#                 [-12.9927448, -38.4937012],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5.044774884131538, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0e18268ec9adc704a29aeef00262a2d2);
#
#
#         var popup_00f83cf271f1993082f6066cd18805e0 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_a73934277b0e8678d1dc2288b829d7bc = $(`&lt;div id=&quot;html_a73934277b0e8678d1dc2288b829d7bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: -12.9927448&lt;br&gt;Longitude: -38.4937012&lt;br&gt;Bairro: Acupe&lt;br&gt;Número de Casos: 122.63&lt;/div&gt;`)[0];
#                 popup_00f83cf271f1993082f6066cd18805e0.setContent(html_a73934277b0e8678d1dc2288b829d7bc);
#
#
#
#         circle_marker_4c0ca6dc8c572f05066d9b4073d7ba3e.bindPopup(popup_00f83cf271f1993082f6066cd18805e0)
#         ;
#
#
#
#
#             circle_marker_4c0ca6dc8c572f05066d9b4073d7ba3e.bindTooltip(
#                 `&lt;div&gt;
#                      Acupe
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_544ba8c018225ee436b27f4d0ca20322 = L.circleMarker(
#                 [-12.9174425, -38.3294749],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0e18268ec9adc704a29aeef00262a2d2);
#
#
#         var popup_3f21ce2c2f6ece697bdcd7c74bb2fc51 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_972e32dce9043fe7bd0e114aaf444b65 = $(`&lt;div id=&quot;html_972e32dce9043fe7bd0e114aaf444b65&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude: -12.9174425&lt;br&gt;Longitude: -38.3294749&lt;br&gt;Bairro: Aeroporto&lt;br&gt;Número de Casos: 0.0&lt;/div&gt;`)[0];
#                 popup_3f21ce2c2f6ece697bdcd7c74bb2fc51.setContent(html_972e32dce9043fe7bd0e114aaf444b65);
#
#
#
#         circle_marker_544ba8c018225ee436b27f4d0ca20322.bindPopup(popup_3f21ce2c2f6ece697bdcd7c74bb2fc51)
#         ;
#
#
#
#
#             circle_marker_544ba8c018225ee436b27f4d0ca20322.bindTooltip(
#                 `&lt;div&gt;
#                      Aeroporto
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_ac84f37015594d9f36f04360e708dd4f = L.circleMarker(
#                 [-12.88806345, -38.43453984517778],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4.260428161553741, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0e18268ec9adc704a29aeef00262a2d2);
#
#
#         var popup_07dc7b63638a3146d40652813c944046 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_e248d2fbad55ff26e0039c9835f18ab8 = $(`&lt;div id=&quot;html_

# %%
df.to_csv('Bairro_maceio_coordendas.csv', index=False)
